# %%
import pandas as pd
df=pd.read_csv('zomato.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
df.drop('rest_type',axis=1,inplace=True)
df.drop('menu_item',axis=1,inplace=True)
df.drop('phone',axis=1,inplace=True)
df.drop('address',axis=1,inplace=True)
df.drop('url',axis=1,inplace=True)

# %%
df.drop('dish_liked',axis=1,inplace=True)

# %% [raw]
# df.drop('reviews_list',axis=1,inplace=True)

# %%
df.drop('reviews_list',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         51717 non-null  object
#  1   online_order                 51717 non-null  object
#  2   book_table                   51717 non-null  object
#  3   rate                         43942 non-null  object
#  4   votes                        51717 non-null  int64
#  5   location                     51696 non-null  object
#  6   cuisines                     51672 non-null  object
#  7   approx_cost(for two people)  51371 non-null  object
#  8   reviews_list                 51717 non-null  object
#  9   listed_in(type)              51717 non-null  object
#  10  listed_in(city)              51717 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 4.3+ MB

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51645 entries, 0 to 51716
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         51645 non-null  object
#  1   online_order                 51645 non-null  object
#  2   book_table                   51645 non-null  object
#  3   rate                         43888 non-null  object
#  4   votes                        51645 non-null  int64
#  5   location                     51624 non-null  object
#  6   cuisines                     51600 non-null  object
#  7   approx_cost(for two people)  51300 non-null  object
#  8   reviews_list                 51645 non-null  object
#  9   listed_in(type)              51645 non-null  object
#  10  listed_in(city)              51645 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 4.7+ MB

# %%
df.rename(columns={"name":"restaurant_name","rate":"rating","listed_in(type)":"restaurant_type"},inplace=True)

# %%
df.rename(columns={"approx_cost(for two people)":"cost_per_person"},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51645 entries, 0 to 51716
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   restaurant_name              51645 non-null  object
#  1   online_order                 51645 non-null  object
#  2   book_table                   51645 non-null  object
#  3   rating                       43888 non-null  object
#  4   votes                        51645 non-null  int64
#  5   location                     51624 non-null  object
#  6   cuisines                     51600 non-null  object
#  7   approx_cost(for two people)  51300 non-null  object
#  8   reviews_list                 51645 non-null  object
#  9   restaurant_type              51645 non-null  object
#  10  listed_in(city)              51645 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 4.7+ MB

# %%
df['rating']=df['rating'].astype(str)
df['rating']=df['rating'].str.replace('/5','')
df['rating']=df['rating'].str.replace('NEW','nan')
df['rating']=df['rating'].str.replace('-','nan')
df['rating']=df['rating'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51645 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   restaurant_name              51645 non-null  object
#  1   online_order                 51645 non-null  object
#  2   book_table                   51645 non-null  object
#  3   rating                       41622 non-null  float64
#  4   votes                        51645 non-null  int64
#  5   location                     51624 non-null  object
#  6   cuisines                     51600 non-null  object
#  7   approx_cost(for two people)  51300 non-null  object
#  8   restaurant_type              51645 non-null  object
#  9   listed_in(city)              51645 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 4.3+ MB

# %%
df=df.dropna(subset=(['cuisines','location','approx_cost(for two people)']))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51281 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   restaurant_name              51281 non-null  object
#  1   online_order                 51281 non-null  object
#  2   book_table                   51281 non-null  object
#  3   rating                       41368 non-null  float64
#  4   votes                        51281 non-null  int64
#  5   location                     51281 non-null  object
#  6   cuisines                     51281 non-null  object
#  7   approx_cost(for two people)  51281 non-null  object
#  8   restaurant_type              51281 non-null  object
#  9   listed_in(city)              51281 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 4.3+ MB

# %%
df['rating']=df['rating'].fillna(df['rating'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51281 entries, 0 to 51716
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   restaurant_name              51281 non-null  object
#  1   online_order                 51281 non-null  object
#  2   book_table                   51281 non-null  object
#  3   rating                       51281 non-null  float64
#  4   votes                        51281 non-null  int64
#  5   location                     51281 non-null  object
#  6   cuisines                     51281 non-null  object
#  7   approx_cost(for two people)  51281 non-null  object
#  8   reviews_list                 51281 non-null  object
#  9   restaurant_type              51281 non-null  object
#  10  listed_in(city)              51281 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 4.7+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51281 entries, 0 to 51716
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   restaurant_name  51281 non-null  object
#  1   online_order     51281 non-null  object
#  2   book_table       51281 non-null  object
#  3   rating           51281 non-null  float64
#  4   votes            51281 non-null  int64
#  5   location         51281 non-null  object
#  6   cuisines         51281 non-null  object
#  7   cost_per_person  51281 non-null  object
#  8   reviews_list     51281 non-null  object
#  9   restaurant_type  51281 non-null  object
#  10  listed_in(city)  51281 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 4.7+ MB

# %%
df['cost_per_person']=df['cost_per_person'].astype(str)
df['cost_per_person'] = df['cost_per_person'].str.replace(',', '')
df['cost_per_person']=df['cost_per_person'].astype(int)
df['cost_per_person'] = df['cost_per_person'] / 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51281 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   restaurant_name  51281 non-null  object
#  1   online_order     51281 non-null  object
#  2   book_table       51281 non-null  object
#  3   rating           51281 non-null  float64
#  4   votes            51281 non-null  int64
#  5   location         51281 non-null  object
#  6   cuisines         51281 non-null  object
#  7   cost_per_person  51281 non-null  float64
#  8   restaurant_type  51281 non-null  object
#  9   listed_in(city)  51281 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 4.3+ MB

# %%
df['restaurant_name']=df['restaurant_name'].astype("string")
df['online_order']=df['online_order'].astype("string")
df['book_table']=df['book_table'].astype("string")
df['location']=df['location'].astype("string")
df['cuisines']=df['cuisines'].astype("string")

# %%
df['restaurant_type']=df['restaurant_type'].astype("string")
df['City']=df['City'].astype("string")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51281 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   restaurant_name  51281 non-null  string
#  1   online_order     51281 non-null  string
#  2   book_table       51281 non-null  string
#  3   rating           51281 non-null  float64
#  4   votes            51281 non-null  int64
#  5   location         51281 non-null  string
#  6   cuisines         51281 non-null  string
#  7   cost_per_person  51281 non-null  float64
#  8   restaurant_type  51281 non-null  object
#  9   listed_in(city)  51281 non-null  object
# dtypes: float64(2), int64(1), object(2), string(5)
# memory usage: 4.3+ MB

# %%
df.rename(columns={"listed_in(city)":"City"},inplace=True)
df.drop('City',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51281 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   restaurant_name  51281 non-null  string
#  1   online_order     51281 non-null  string
#  2   book_table       51281 non-null  string
#  3   rating           51281 non-null  float64
#  4   votes            51281 non-null  int64
#  5   location         51281 non-null  string
#  6   cuisines         51281 non-null  string
#  7   cost_per_person  51281 non-null  float64
#  8   restaurant_type  51281 non-null  string
#  9   City             51281 non-null  string
# dtypes: float64(2), int64(1), string(7)
# memory usage: 4.3 MB

# %%
df.to_csv('zomato_clean_data.csv', index=False)
